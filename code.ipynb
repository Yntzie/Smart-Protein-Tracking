# %%
# Blok 1: Install & Import
# !pip install pandas fuzzywuzzy python-Levenshtein streamlit
import pandas as pd
import sqlite3
import re
from fuzzywuzzy import process
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 37.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 39.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.9 MB/s eta 0:00:00
# ...

# %%
def load_nutrition_db():
    data = {
        'food_item': [
            'dada ayam', 'paha ayam', 'telur', 'telur rebus', 'telur goreng', 
            'tempe', 'tahu', 'daging sapi', 'ikan salmon', 'ikan nila', 
            'ikan tongkol', 'whey protein', 'susu sapi', 'kacang tanah', 'nasi putih'
        ],
        'protein_per_100g': [
            31.0, 26.0, 13.0, 13.0, 13.0, 
            19.0, 8.0, 26.0, 20.0, 26.0, 
            24.0, 80.0, 3.4, 25.0, 2.7
        ],
        'unit': [
            'gram', 'gram', 'butir', 'butir', 'butir', 
            'gram', 'gram', 'gram', 'gram', 'gram', 
            'gram', 'gram', 'ml', 'gram', 'gram'
        ]
    }
    return pd.DataFrame(data)
# Out:
# Database nutrisi siap!

# %%
# Blok 3: SQLite Setup untuk Riwayat Makan
def init_db():
    conn = sqlite3.connect('gym_tracker.db')
    c = conn.cursor()
    c.execute('''CREATE TABLE IF NOT EXISTS logs
                 (date TEXT, food TEXT, protein REAL)''')
    conn.commit()
    conn.close()

init_db()
print("Database riwayat (SQLite) berhasil dibuat!")
# Out:
# Database riwayat (SQLite) berhasil dibuat!

# %%
# %run app.py
# Out:
# 2026-04-28 08:43:42.113 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-28 08:43:42.115 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-28 08:43:42.291
# ...
#   command:
#
#     streamlit run app.py [ARGUMENTS]
# 2026-04-28 08:43:42.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-28 08:43:42.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-28 08:43:42.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-28 08:43:42.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
